# %%
import pandas as pd
import numpy as np
import matplotlib
import datetime

import matplotlib.pyplot as plt

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
aapl = pd.read_csv('datasets/AAPL.csv')

aapl.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 1  2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 2  2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 3  2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 4  2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#       Volume
# 0  174259400
# 1  103856900
# 2  130197200
# 3   85639400
# 4  131637800

# %%
aapl = aapl.sample(frac=1)

aapl.reset_index(inplace=True, drop=True)

aapl.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-05-15   62.737144   63.000000   60.337143   61.264286   54.614445
# 1  2010-10-14   43.098572   43.209999   42.914288   43.187141   37.689987
# 2  2014-04-21   75.048569   76.019997   74.851425   75.881432   68.899124
# 3  2015-01-23  112.300003  113.750000  111.529999  112.980003  104.119629
# 4  2018-09-17  222.149994  222.949997  217.270004  217.880005  214.550659
#
#       Volume
# 0  185403400
# 1  108824100
# 2   45637200
# 3   46464800
# 4   37195100

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
# Date         2265 non-null object
# Open         2265 non-null float64
# High         2265 non-null float64
# Low          2265 non-null float64
# Close        2265 non-null float64
# Adj Close    2265 non-null float64
# Volume       2265 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 124.0+ KB

# %%
aapl['Date'] = pd.to_datetime(aapl['Date'])

aapl.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2013-05-15   62.737144   63.000000   60.337143   61.264286   54.614445
# 1 2010-10-14   43.098572   43.209999   42.914288   43.187141   37.689987
# 2 2014-04-21   75.048569   76.019997   74.851425   75.881432   68.899124
# 3 2015-01-23  112.300003  113.750000  111.529999  112.980003  104.119629
# 4 2018-09-17  222.149994  222.949997  217.270004  217.880005  214.550659
#
#       Volume
# 0  185403400
# 1  108824100
# 2   45637200
# 3   46464800
# 4   37195100

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
# Date         2265 non-null datetime64[ns]
# Open         2265 non-null float64
# High         2265 non-null float64
# Low          2265 non-null float64
# Close        2265 non-null float64
# Adj Close    2265 non-null float64
# Volume       2265 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 124.0 KB

# %%
aapl.shape
# Out:
# (2265, 7)

# %%
aapl.sort_values(by='Date', inplace=True)

aapl.head()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 1487 2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 891  2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 619  2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 1187 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 862  2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#          Volume
# 1487  174259400
# 891   103856900
# 619   130197200
# 1187   85639400
# 862   131637800

# %%
aapl.reset_index(inplace=True, drop=True)

aapl.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463  174259400
# 1 2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864  103856900
# 2 2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719  130197200
# 3 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021   85639400
# 4 2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102  131637800

# %%
aapl['Date'] = aapl['Date'].apply(lambda d: d.to_pydatetime())

aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
# Date         2265 non-null datetime64[ns]
# Open         2265 non-null float64
# High         2265 non-null float64
# Low          2265 non-null float64
# Close        2265 non-null float64
# Adj Close    2265 non-null float64
# Volume       2265 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 124.0 KB

# %%
aapl['Weekday'] = aapl['Date'].apply(lambda d: d.isoweekday())

aapl.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 1 2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 2 2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 3 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 4 2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#       Volume  Weekday
# 0  174259400        3
# 1  103856900        4
# 2  130197200        5
# 3   85639400        2
# 4  131637800        3

# %%
extract_year = lambda x: datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").year

# %%
aapl['Year'] = aapl['Date'].apply(extract_year)

aapl.sample(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 2029 2018-09-24  216.820007  221.259995  216.630005  220.789993  217.416183
# 126  2011-03-03   51.027142   51.398571   50.845715   51.365715   44.827538
# 2147 2019-03-15  184.850006  187.330002  183.740005  186.119995  184.704224
# 184  2011-05-25   47.632858   48.365715   47.549999   48.111427   41.987469
# 1166 2015-04-22  126.989998  128.869995  126.320000  128.619995  119.000900
# 2027 2018-09-20  220.240005  222.279999  219.149994  220.029999  216.667816
# 1072 2014-12-04  115.769997  117.199997  115.290001  115.489998  106.432808
# 832  2013-12-20   77.918571   78.801430   77.831429   78.431427   70.790741
# 646  2013-03-28   64.260002   64.545715   63.088570   63.237144   56.002468
# 1312 2015-11-17  114.919998  115.050003  113.320000  113.690002  106.559135
#
#          Volume  Weekday  Year
# 2029   27693400        1  2018
# 126   125197100        4  2011
# 2147   39042900        5  2019
# 184    73556000        3  2011
# 1166   37654500        3  2015
# 2027   26608800        4  2018
# 1072   42044500        4  2014
# 832   109103400        5  2013
# 646   110709900        4  2013
# 1312   27616900        2  2015

# %%
extract_month = lambda x: datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").month

# %%
aapl['Month'] = aapl['Date'].apply(extract_month)

aapl.sample(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1852 2018-01-10  173.160004  174.300003  173.000000  174.289993  169.678162
# 1734 2017-07-24  150.580002  152.440002  149.899994  152.089996  146.958130
# 39   2010-10-27   43.950001   44.271427   43.657143   43.975716   38.378185
# 736  2013-08-06   66.860001   67.412857   66.024284   66.464287   59.250011
# 1392 2016-03-15  103.959999  105.180000  103.849998  104.580002   98.552414
# 1843 2017-12-27  170.100006  170.779999  169.710007  170.600006  166.085815
# 1589 2016-12-22  116.349998  116.510002  115.639999  116.290001  111.421135
# 29   2010-10-13   42.885715   43.137142   42.828571   42.877144   37.419449
# 1937 2018-05-14  189.009995  189.529999  187.860001  188.149994  184.627441
# 798  2013-11-01   74.860001   74.971428   73.691429   74.290001   66.663559
#
#          Volume  Weekday  Year  Month
# 1852   23959900        3  2018      1
# 1734   21493200        1  2017      7
# 39     99750700        3  2010     10
# 736    83714400        2  2013      8
# 1392   40067700        2  2016      3
# 1843   21498200        3  2017     12
# 1589   26085900        4  2016     12
# 29    157523100        3  2010     10
# 1937   20778800        1  2018      5
# 798    68722500        5  2013     11

# %%
plt.figure(figsize=(10, 8))

plt.plot(aapl['Date'], 
         aapl['Close'])


plt.xlabel('Date')
plt.ylabel('AAPL stock price')

plt.show()

# %%
aapl_by_month = aapl.groupby(by='Month').mean()

aapl_by_month
# Out:
#              Open        High         Low       Close   Adj Close  \
# Month
# 1      101.994535  102.918907  100.951405  101.984114   95.751760
# 2      105.731883  106.824278  104.926416  105.957919   99.758569
# 3      110.966491  111.905912  109.954652  110.932645  104.567909
# 4      113.209677  114.178134  112.210968  113.190253  106.801941
# 5      114.985700  116.054071  114.072117  115.136299  109.015417
# 6      114.861189  115.727824  113.905445  114.763380  108.690969
# 7      118.451053  119.374985  117.628308  118.553113  112.321209
# 8      123.594762  124.837491  122.504158  123.739922  117.636038
# 9      106.138392  107.083427  105.041077  106.015301   99.328919
# 10     108.965033  110.002988  107.843502  108.991740  102.258505
# 11     106.816479  107.740888  105.663429  106.738062  100.328575
# 12     102.733191  103.636634  101.636406  102.549392   96.163693
#
#              Volume   Weekday         Year
# Month
# 1      7.937537e+07  3.109290  2015.016393
# 2      7.453773e+07  3.092486  2014.988439
# 3      7.219678e+07  3.010256  2014.979487
# 4      7.514483e+07  2.903226  2015.005376
# 5      6.305513e+07  3.103627  2015.020725
# 6      5.563672e+07  3.020942  2014.984293
# 7      5.575913e+07  2.957895  2015.010526
# 8      6.634713e+07  3.029851  2015.000000
# 9      8.456097e+07  3.114754  2013.967213
# 10     8.016695e+07  2.989848  2014.050761
# 11     7.033131e+07  2.962162  2014.000000
# 12     6.463759e+07  3.021277  2013.936170

# %%
plt.figure(figsize=(10, 8))

plt.plot(aapl_by_month.index, 
         aapl_by_month['Close'])


plt.xlabel('Date')
plt.ylabel('AAPL stock price')

plt.show()
